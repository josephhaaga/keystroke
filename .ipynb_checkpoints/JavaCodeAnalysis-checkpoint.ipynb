# %%
import pandas as pd;
import numpy as np;

# The quick brown fox jumped over the lazy dog

# %%
file1 = pd.read_csv('final/quick_brown_fox/joehaaga/Sun Sep 25 13:50:34 EDT 2016.txt',sep="    ",header=None);
# Out:
# /home/joseph/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
file1 = file1.drop([3],axis=1)

# %%
file1
# Out:
#                    0                     1                    2  \
# 0     KEY PRESSED: n   kCode = 16 (Shift)n   mods = 64 (Shift)n
# 1     KEY PRESSED: n       kCode = 84 (T)n   mods = 64 (Shift)n
# 2       KEY TYPED: n        key str = 'T'n   mods = 64 (Shift)n
# 3    KEY RELEASED: n   kCode = 16 (Shift)n  mods = 0 (no mods)n
# 4    KEY RELEASED: n       kCode = 84 (T)n  mods = 0 (no mods)n
# 5     KEY PRESSED: n       kCode = 72 (H)n  mods = 0 (no mods)n
# 6       KEY TYPED: n        key str = 'h'n  mods = 0 (no mods)n
# 7    KEY RELEASED: n       kCode = 72 (H)n  mods = 0 (no mods)n
# 8     KEY PRESSED: n       kCode = 69 (E)n  mods = 0 (no mods)n
# 9       KEY TYPED: n        key str = 'e'n  mods = 0 (no mods)n
# 10   KEY RELEASED: n       kCode = 69 (E)n  mods = 0 (no mods)n
# 11    KEY PRESSED: n   kCode = 32 (Space)n  mods = 0 (no mods)n
# 12      KEY TYPED: n        key str = ' 'n  mods = 0 (no mods)n
# 13   KEY RELEASED: n   kCode = 32 (Space)n  mods = 0 (no mods)n
# ...

# %%
uniques = file1[1].unique()
df = pd.DataFrame(index=uniques)

# %%
for i in uniques:
    print (i)
# Out:
# kCode = 16 (Shift)n
# kCode = 84 (T)n
# key str = 'T'n
# kCode = 72 (H)n
# key str = 'h'n
# kCode = 69 (E)n
# key str = 'e'n
# kCode = 32 (Space)n
# key str = ' 'n
# kCode = 81 (Q)n
# key str = 'q'n
# kCode = 85 (U)n
# key str = 'u'n
# kCode = 73 (I)n
# key str = 'i'n
# kCode = 67 (C)n
# key str = 'c'n
# kCode = 75 (K)n
# key str = 'k'n
# kCode = 66 (B)n
# key str = 'b'n
# kCode = 82 (R)n
# key str = 'r'n
# kCode = 79 (O)n
# key str = 'o'n
# kCode = 87 (W)n
# key str = 'w'n
# kCode = 78 (N)n
# key str = 'n'n
# kCode = 70 (F)n
# key str = 'f'n
# kCode = 88 (X)n
# key str = 'x'n
# kCode = 74 (J)n
# key str = 'j'n
# kCode = 77 (M)n
# key str = 'm'n
# kCode = 80 (P)n
# key str = 'p'n
# kCode = 68 (D)n
# key str = 'd'n
# kCode = 86 (V)n
# key str = 'v'n
# key str = 't'n
# kCode = 76 (L)n
# key str = 'l'n
# kCode = 65 (A)n
# key str = 'a'n
# kCode = 90 (Z)n
# key str = 'z'n
# kCode = 89 (Y)n
# key str = 'y'n
# kCode = 71 (G)n
# key str = 'g'n
# kCode = 46 (Period)n
# key str = '.'n

# %%
for i in df.index:
    print (i)
    print (file1[file1[1]==i])
    print ('~~~~~~~~~~~~~~~~~~~~')
    print ('\n\n')
# Out:
# kCode = 16 (Shift)n
#                  0                    1                    2  \
# 0   KEY PRESSED: n  kCode = 16 (Shift)n   mods = 64 (Shift)n
# 3  KEY RELEASED: n  kCode = 16 (Shift)n  mods = 0 (no mods)n
#
#                                     4
# 0  key location: rightn 1474825827930
# 3  key location: rightn 1474825828126
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
# kCode = 84 (T)n
#                    0                1                    2  \
# 1     KEY PRESSED: n  kCode = 84 (T)n   mods = 64 (Shift)n
# 4    KEY RELEASED: n  kCode = 84 (T)n  mods = 0 (no mods)n
# 98    KEY PRESSED: n  kCode = 84 (T)n  mods = 0 (no mods)n
# 102  KEY RELEASED: n  kCode = 84 (T)n  mods = 0 (no mods)n
#
#                                          4
# 1    key location: standardn 1474825828074
# 4    key location: standardn 1474825828151
# 98   key location: standardn 1474825831928
# 102  key location: standardn 1474825831994
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
# key str = 'T'n
# ...
