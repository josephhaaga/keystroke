# %%
import pandas as pd
fileOne = pd.read_csv('Joseph1.csv',header=None);
fileTwo = pd.read_csv('Joseph2.csv',header=None);
fileThree = pd.read_csv('Joseph3.csv',header=None);
fileOne.columns=['action','key','timestamp'];
fileTwo.columns=['action','key','timestamp'];
fileThree.columns=['action','key','timestamp'];

# %%
fileOne
# Out:
#       action    key  timestamp
# 0    keydown  Shift    2752567
# 1    keydown      J    2752737
# 2   keypress      J    2752738
# 3      keyup      J    2752856
# 4      keyup  Shift    2752887
# 5    keydown      o      27530
# 6   keypress      o      27531
# 7      keyup      o    2753104
# 8    keydown      s    2753168
# 9   keypress      s    2753169
# 10   keydown      e    2753280
# 11  keypress      e    2753281
# 12     keyup      s    2753303
# 13   keydown      p    2753392
# 14  keypress      p    2753393
# 15     keyup      e    2753431
# 16   keydown      h    2753472
# 17  keypress      h    2753473
# 18     keyup      p    2753519
# 19     keyup      h    2753599

# %%
fileTwo
# Out:
#            0      1        2
# 0    keydown  Shift   289199
# 1    keydown      J   289392
# 2   keypress      J   289393
# 3      keyup      J   289519
# 4      keyup  Shift   289534
# 5    keydown      o   289647
# 6   keypress      o   289648
# 7      keyup      o   289735
# 8    keydown      s   289743
# 9   keypress      s   289744
# 10   keydown      e   289815
# 11  keypress      e   289816
# 12   keydown      p   289871
# 13  keypress      p   289873
# 14     keyup      s   289878
# 15     keyup      e   289959
# 16   keydown      h   289980
# 17  keypress      h   289981
# 18     keyup      p    28107
# 19     keyup      h  2810111
